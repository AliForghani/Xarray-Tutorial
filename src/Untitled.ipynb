# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
ds = xr.open_dataset("../data/AFRICA_WTD_annualmean.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 8760, lon: 8880, time: 1)
# Coordinates:
#   * lat      (lat) float32 -35.0 -34.99 -34.98 -34.97 ... 37.97 37.98 37.99 38.0
#   * lon      (lon) float32 -19.0 -18.99 -18.98 -18.97 ... 54.97 54.98 54.99 55.0
#   * time     (time) int8 1
# Data variables:
#     mask     (lat, lon) int8 ...
#     WTD      (time, lat, lon) float64 ...
# Attributes:
#     disclaimer:      These data can be used freely for research purposes prov...
#     reference:       Fan Y, Miguez-Macho G, Jobbágy EG, Jackson RB, Otero-Cas...
#     project:         EartH2Observe
#     acknowledgment:  The EartH2Observe project has received funding from the ...
#     creator_name:    Gonzalo Miguez-Macho
#     institution:     Universidade de Santiago de Compostela
#     email:           gonzalo.miguez@usc.es
